# %% [markdown]
# <a href="https://colab.research.google.com/github/DronadulaRohit/SE-lab-task-2/blob/main/module_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f1=open("sat.txt",'r')
print(f1.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-cd1e2ab60fba> in <cell line: 1>()
# ----> 1 f1=open("sat.txt",'r')
#       2 print(f1.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sat.txt'

# %%
d=open('sample.txt','wb')
print('sat',d.name)
# Out:
# sat sample.txt

# %%
d1=open('sample.txt','w')
d1.write("hello world")
# Out:
# 11

# %%
d1=open('sample.txt','w')
d1.write("hello world")
print(d1)
print("hahahahha")
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='w' encoding='UTF-8'>
# hahahahha
